# %% [markdown]
# # 🕵️‍♀️ Searching for MGnify Studies
#
# <button title="Make live" style="display:inline-flex;align-items:center;gap:0.4rem;padding:0.5rem 1rem;border:0;border-radius:100px;background:linear-gradient(135deg,#0f766e,#14b8a6);color:white;box-shadow:0 6px 18px rgba(15,118,110,.25);cursor:pointer;font-size:1rem;" class="thebe-button" onclick="initThebeSBT()">Activate Notebook</button>
#
# On this page, which also serves as a runnable notebook (link above ^), we again demonstrate the basic usability of MGni.py to search the [Studies resource](https://www.ebi.ac.uk/metagenomics/api/v2/#/Studies/list_mgnify_studies) for some studies of interest (e.g., tomaotos)
#
# ---
#
# ## 🎯 The Goal: Get a list of MGnify studies of tomato rhizospheres
#
# Let's request tomato rhizosphere study metadata from the  MGnify Studies API.

# %%
# uncomment below if colab
#!pip install mgnipy
#!pip install asyncio

# %%
from mgnipy import MGnipy

MG = MGnipy()

tomato_studies = MG.studies(
    biome_lineage="root:Host-associated:Plants:Rhizosphere", search="tomato"
)

# tomato_studies.explain()
# Out:
# https://www.ebi.ac.uk/metagenomics/api/v2/studies?biome_lineage=root%3AHost-associated%3APlants%3ARhizosphere&search=tomato&page=1

# %% [markdown]
# Choose your entry resource proxy

# %%
# init
MG = MGnipy(
    # configuration
)

# helper
MG.list_resources()
# Out:
# Advancing to request num 1
#        accession             ena_accessions  \
# 0   MGYS00010296    [ERP166137, PRJEB82448]
# 1   MGYS00010297   [SRP333165, PRJNA755742]
# 2   MGYS00006231    [ERP139927, PRJEB55060]
# 3   MGYS00006204    [ERP140102, PRJEB55219]
# 4   MGYS00006205    [ERP140107, PRJEB55224]
# 5   MGYS00006230    [ERP139923, PRJEB55057]
# 6   MGYS00006208    [ERP140115, PRJEB55232]
# 7   MGYS00010257  [SRP456588, PRJNA1004080]
# 8   MGYS00010258  [SRP517058, PRJNA1127303]
# 9   MGYS00010324               [PRJEB95772]
# 10  MGYS00010245    [PRJEB82447, ERP166136]
# 11  MGYS00010298   [PRJNA777724, SRP344777]
# 12  MGYS00010262               [PRJEB91684]
# 13  MGYS00010250   [PRJNA755741, SRP333163]
# 14  MGYS00010264               [PRJEB91717]
# 15  MGYS00010251   [SRP338795, PRJNA766489]
# 16  MGYS00010253   [PRJNA789467, SRP351203]
#
#                                                 title  \
# 0   Microbiome-mediated tolerance of wild tomato t...
# 1   Tomato rhizosphere microbiome in the pot exper...
# 2   EMG produced TPA metagenomics assembly of PRJN...
# 3   EMG produced TPA metagenomics assembly of PRJN...
# 4   EMG produced TPA metagenomics assembly of PRJN...
# 5   EMG produced TPA metagenomics assembly of PRJN...
# 6   EMG produced TPA metagenomics assembly of PRJN...
# 7   Combined effect of microplastics and fungicide...
# 8   Metagenomic data of rhizosphere soil during to...
# 9   Metagenome assembly of PRJNA777724 data set (T...
# 10  Unveiling diversity and adaptations of the wil...
# 11                        Tomato heritable microbiome
# 12  Metagenome assembly of PRJNA1004080 data set (...
# 13  Tomato rhizosphere microbiome in the belowgrou...
# 14  Metagenome assembly of PRJNA1127303 data set (...
# 15  Culture-independent analysis of rhizosphere mi...
# 16  Disentangling the genetic basis of rhizosphere...
#
#                                                 biome  \
# 0   {'biome_name': 'Rhizosphere', 'lineage': 'root...
# 1   {'biome_name': 'Rhizosphere', 'lineage': 'root...
# 2   {'biome_name': 'Rhizosphere', 'lineage': 'root...
# 3   {'biome_name': 'Rhizosphere', 'lineage': 'root...
# 4   {'biome_name': 'Rhizosphere', 'lineage': 'root...
# 5   {'biome_name': 'Rhizosphere', 'lineage': 'root...
# 6   {'biome_name': 'Rhizosphere', 'lineage': 'root...
# 7   {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 8   {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 9   {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 10  {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 11  {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 12  {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 13  {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 14  {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 15  {'biome_name': 'Soil', 'lineage': 'root:Host-a...
# 16  {'biome_name': 'Soil', 'lineage': 'root:Host-a...
#
#                           updated_at
# 0   2025-07-23T14:00:52.352000+00:00
# 1   2025-07-23T11:42:02.227000+00:00
# 2   2026-04-30T22:27:28.963000+00:00
# 3   2026-04-30T22:01:19.102000+00:00
# 4   2026-04-30T22:01:31.666000+00:00
# 5   2026-04-30T22:25:40.059000+00:00
# 6   2026-04-30T22:01:49.848000+00:00
# 7   2025-07-03T18:47:35.095000+00:00
# 8   2025-07-04T11:04:15.175000+00:00
# 9   2025-08-07T12:30:16.888000+00:00
# 10  2025-07-23T16:38:33.334000+00:00
# 11  2025-08-07T15:25:59.939000+00:00
# 12  2025-07-03T18:41:58.194000+00:00
# 13  2025-07-23T08:45:47.142000+00:00
# 14  2025-07-04T10:10:15.643000+00:00
# 15  2025-07-21T17:01:18.132000+00:00
# 16  2025-08-01T17:26:35.948000+00:00

# %% [markdown]
# you can either pass query parameters as dict to `params` or as kwargs.

# %%
# studies resource proxy
studies = MG.studies

# helper
studies.list_supported_params()

# %%
# set up query
filtered_studies = studies.filter(
    biome_lineage="root:Host-associated:Plants:Rhizosphere", search="tomato"
)

# preview before getting all pages
filtered_studies.dry_run()

# %%
# make the get request
await filtered_studies.abulk_fetch()

# look at our list of studies
filtered_studies.to_df()

# %% [markdown]
# ### Getting their study details
#
# From our filtered list of studies we can use `.get_detail()` to iteratively get their details from the [**get_mgnify_study** MGnify API endpoint](https://www.ebi.ac.uk/metagenomics/api/v2/#/Studies/get_mgnify_study)

# %%
# get details for all studies (this will make multiple requests until all details are fetched)
while True:
    # get details for the next study
    det = filtered_studies.get_detail()
    # if no more studies to fetch details for, break the loop
    if det is None:
        print("Finished fetching details for all studies.")
        break
# Out:
# Finished fetching details for all studies.

# %% [markdown]
# We can take a look at all study metadata details which are stored to
#
# - `.details`: the `mgnipy.StudyDetail` instances
# - `.details_rsults`: a dictionary where each item is a accession: detail
# - `.details_df`: a pd.DataFrame where each study metadata detail is a row

# %%
filtered_studies.details_df
# Out:
#                  accession            ena_accessions  \
# MGYS00010296  MGYS00010296   [ERP166137, PRJEB82448]
# MGYS00010297  MGYS00010297  [SRP333165, PRJNA755742]
# MGYS00006231  MGYS00006231   [ERP139927, PRJEB55060]
# MGYS00006204  MGYS00006204   [ERP140102, PRJEB55219]
# MGYS00006205  MGYS00006205   [ERP140107, PRJEB55224]
#
#                                                           title  \
# MGYS00010296  Microbiome-mediated tolerance of wild tomato t...
# MGYS00010297  Tomato rhizosphere microbiome in the pot exper...
# MGYS00006231  EMG produced TPA metagenomics assembly of PRJN...
# MGYS00006204  EMG produced TPA metagenomics assembly of PRJN...
# MGYS00006205  EMG produced TPA metagenomics assembly of PRJN...
#
#                                                           biome  \
# MGYS00010296  {'biome_name': 'Rhizosphere', 'lineage': 'root...
# MGYS00010297  {'biome_name': 'Rhizosphere', 'lineage': 'root...
# MGYS00006231  {'biome_name': 'Rhizosphere', 'lineage': 'root...
# MGYS00006204  {'biome_name': 'Rhizosphere', 'lineage': 'root...
# MGYS00006205  {'biome_name': 'Rhizosphere', 'lineage': 'root...
#
#                                     updated_at  \
# MGYS00010296  2025-07-23T14:00:52.352000+00:00
# MGYS00010297  2025-07-23T11:42:02.227000+00:00
# MGYS00006231  2026-04-30T22:27:28.963000+00:00
# MGYS00006204  2026-04-30T22:01:19.102000+00:00
# MGYS00006205  2026-04-30T22:01:31.666000+00:00
#
#                                                       downloads metadata  \
# MGYS00010296                                                 []       {}
# MGYS00010297                                                 []       {}
# MGYS00006231  [{'file_type': 'tsv', 'download_type': 'Taxono...       {}
# MGYS00006204  [{'file_type': 'tsv', 'download_type': 'Taxono...       {}
# MGYS00006205  [{'file_type': 'tsv', 'download_type': 'Taxono...       {}
#
#              first_accession
# MGYS00010296       ERP166137
# MGYS00010297       SRP333165
# MGYS00006231       ERP139927
# MGYS00006204       ERP140102
# MGYS00006205       ERP140107

# %% [markdown]
# ## 🎯 Next Steps: Getting their MGnify analyses
#
# Using the StudyDetail instances we can also get a list of all their
# - MGnify analyses i.e., `mgnipy.V2.proxies.Analyses` instance
# - publications `mgnipy.V2.proxies.Publications`
# - samples `mgnipy.V2.proxies.Samples`

# %% [markdown]
# For example lets take a look at the study "MGYS00006204".

# %% [markdown]
# ### Step-by-step example: `MGYS00006204`

# %%
# getting the StudyDetail for the specific study
example_study_details = filtered_studies["MGYS00006231"]

# this is a helper method to list all relationships for the study
example_study_details.list_relationships()
# Out:
# ['samples', 'analyses', 'publications']

# %% [markdown]
# we can access them as attributes form the StudyDetail. When called the requests will automatically be made to the MGnify API

# %%
example_study_pub_list = example_study_details.publications
print(example_study_pub_list)

example_study_sample_list = example_study_details.samples
print(example_study_sample_list)

example_study_analysis_list = example_study_details.analyses
print(example_study_analysis_list)
# Out:
# Retrieving pages: 100%|██████████| 1/1 [00:00<00:00, 2525.17it/s]
# Advancing to request num 1
# MGnifier instance for resource: publications
# I.e., mgnipy.V2.proxies.publications.Publications
# ----------------------------------------
# Base URL: https://www.ebi.ac.uk/
# Parameters: {'accession': 'MGYS00006231'}
# Example request URL: https://www.ebi.ac.uk/metagenomics/api/v2/studies/MGYS00006231/publications?page=1
# Endpoint module: mgnipy.emgapi_v2_client.api.studies.list_mgnify_study_publications
# Is list endpoint (returns paginated results): True
# Cache directory: /Users/phanthanourak/Library/Caches/mgnipy/9be351d43240b5e84bc0968397a25d600e05060b7e43fe51945d866f35d01c28
# Retrieving pages: 100%|██████████| 5/5 [00:00<00:00, 8153.78it/s]
# Advancing to request num 1
# Advancing to request num 2
# Advancing to request num 3
# Advancing to request num 4
# Advancing to request num 5
# MGnifier instance for resource: samples
# I.e., mgnipy.V2.proxies.samples.Samples
# ----------------------------------------
# Base URL: https://www.ebi.ac.uk/
# Parameters: {'accession': 'MGYS00006231'}
# Example request URL: https://www.ebi.ac.uk/metagenomics/api/v2/studies/MGYS00006231/samples?page=1
# Endpoint module: mgnipy.emgapi_v2_client.api.studies.list_mgnify_study_samples
# Is list endpoint (returns paginated results): True
# Cache directory: /Users/phanthanourak/Library/Caches/mgnipy/5ba3912237f2b3ec1baa3a302cd5c6ff7340cfc88d6512cd2c1eae5f8aa29648
# Retrieving pages: 100%|██████████| 5/5 [00:00<00:00, 4464.88it/s]
# Advancing to request num 1
# Advancing to request num 2
# Advancing to request num 3
# Advancing to request num 4
# Advancing to request num 5
# MGnifier instance for resource: analyses
# I.e., mgnipy.V2.proxies.analyses.Analyses
# ----------------------------------------
# Base URL: https://www.ebi.ac.uk/
# Parameters: {'accession': 'MGYS00006231'}
# Example request URL: https://www.ebi.ac.uk/metagenomics/api/v2/studies/MGYS00006231/analyses?page=1
# Endpoint module: mgnipy.emgapi_v2_client.api.studies.list_mgnify_study_analyses
# Is list endpoint (returns paginated results): True
# Cache directory: /Users/phanthanourak/Library/Caches/mgnipy/e17f20b39bbe95d0d44c64473835e35ad2343868b51e44ecaca4d021a1a8cdd9

# %% [markdown]
# taking a look at the analyses metadata

# %%
example_study_analysis_list.to_df()
# Out:
#     experiment_type study_accession     accession   run  \
# 0          Assembly    MGYS00006231  MGYA00645526  None
# 1          Assembly    MGYS00006231  MGYA00645548  None
# 2          Assembly    MGYS00006231  MGYA00645551  None
# 3          Assembly    MGYS00006231  MGYA00645559  None
# 4          Assembly    MGYS00006231  MGYA00645571  None
# ..              ...             ...           ...   ...
# 109        Assembly    MGYS00006231  MGYA00793502  None
# 110        Assembly    MGYS00006231  MGYA00793503  None
# 111        Assembly    MGYS00006231  MGYA00793504  None
# 112        Assembly    MGYS00006231  MGYA00793505  None
# 113        Assembly    MGYS00006231  MGYA00793506  None
#
#                                                 sample  \
# 0    {'accession': 'SAMN24114695', 'ena_accessions'...
# 1    {'accession': 'SAMN24114734', 'ena_accessions'...
# 2    {'accession': 'SAMN24114802', 'ena_accessions'...
# 3    {'accession': 'SAMN24114786', 'ena_accessions'...
# 4    {'accession': 'SAMN24114738', 'ena_accessions'...
# ..                                                 ...
# 109  {'accession': 'SAMN24114780', 'ena_accessions'...
# 110  {'accession': 'SAMN24114748', 'ena_accessions'...
# 111  {'accession': 'SAMN24114732', 'ena_accessions'...
# 112  {'accession': 'SAMN24114749', 'ena_accessions'...
# 113  {'accession': 'SAMN24114800', 'ena_accessions'...
#
#                                               assembly pipeline_version
# 0    {'updated_at': '2026-04-30T22:25:40.680000+00:...               V5
# 1    {'updated_at': '2026-04-30T22:25:41.667000+00:...               V5
# 2    {'updated_at': '2026-04-30T22:25:42.609000+00:...               V5
# 3    {'updated_at': '2026-04-30T22:25:43.561000+00:...               V5
# 4    {'updated_at': '2026-04-30T22:25:44.649000+00:...               V5
# ..                                                 ...              ...
# 109  {'updated_at': '2026-04-30T22:27:23.689000+00:...               V5
# 110  {'updated_at': '2026-04-30T22:27:24.599000+00:...               V5
# 111  {'updated_at': '2026-04-30T22:27:25.517000+00:...               V5
# 112  {'updated_at': '2026-04-30T22:27:26.440000+00:...               V5
# 113  {'updated_at': '2026-04-30T22:27:27.357000+00:...               V5
#
# [114 rows x 7 columns]

# %% [markdown]
# then we can get the details and so on

# %% [markdown]
# ### On Repeat: Getting all analyses metadata
#
# - loop through every study in `filtered_studies.detail`
# - for each study get the details on all sample analyses appending to a list `analyses_details`
# - then we will take a look as a dataframe

# %%
import asyncio

study_details_dict = filtered_studies.details

analyses_details = []

for study_id, study_detail in study_details_dict.items():

    # verbose
    print(f"Study {study_id}")

    # populating list of analyses for the study
    study_analyses_list = study_detail.analyses

    # get the analyses details
    while True:
        # get details for the next analysis
        det = await study_analyses_list.aget_detail()
        # adding a delay to avoid overwhelming the API
        await asyncio.sleep(0.5)
        # if no more analyses to fetch details for, break the loop
        if det is None:
            print("Finished fetching details for all analyses.")
            break

    print(
        f"Number of analyses for study {study_id}: {len(study_analyses_list)}\n"
    )

    analyses_details.append(study_analyses_list.details_df)
# Out:
# Study MGYS00010296
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010296: 0
#
# Study MGYS00010297
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010297: 0
#
# Study MGYS00006231
# Retrieving pages: 100%|██████████| 5/5 [00:00<00:00, 5235.03it/s]
# Advancing to request num 1
# Advancing to request num 2
# Advancing to request num 3
# Advancing to request num 4
# Advancing to request num 5
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00006231: 114
#
# Study MGYS00006204
# Retrieving pages: 100%|██████████| 1/1 [00:00<00:00, 5412.01it/s]
# Advancing to request num 1
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00006204: 12
#
# Study MGYS00006205
# Retrieving pages: 100%|██████████| 1/1 [00:00<00:00, 3518.71it/s]
# Advancing to request num 1
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00006205: 12
#
# Study MGYS00006230
# Retrieving pages: 100%|██████████| 1/1 [00:00<00:00, 4544.21it/s]
# Advancing to request num 1
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00006230: 2
#
# Study MGYS00006208
# Retrieving pages: 100%|██████████| 1/1 [00:00<00:00, 3876.44it/s]
# Advancing to request num 1
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00006208: 9
#
# Study MGYS00010257
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010257: 0
#
# Study MGYS00010258
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010258: 0
#
# Study MGYS00010324
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010324: 0
#
# Study MGYS00010245
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010245: 0
#
# Study MGYS00010298
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010298: 0
#
# Study MGYS00010262
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010262: 0
#
# Study MGYS00010250
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010250: 0
#
# Study MGYS00010264
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010264: 0
#
# Study MGYS00010251
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010251: 0
#
# Study MGYS00010253
# Retrieving pages: 0it [00:00, ?it/s]
# Finished fetching details for all analyses.
# Number of analyses for study MGYS00010253: 0

# %% [markdown]
# let's look at all the sample analyses metadata in one df

# %%
import pandas as pd

# concat the list of analyses details dataframes into one dataframe
tomato_analyses = pd.concat(analyses_details)
# take a look
print(tomato_analyses.shape)
tomato_analyses.head()
# Out:
# (149, 12)
#              experiment_type study_accession     accession   run  \
# MGYA00645526        Assembly    MGYS00006231  MGYA00645526  None
# MGYA00645548        Assembly    MGYS00006231  MGYA00645548  None
# MGYA00645551        Assembly    MGYS00006231  MGYA00645551  None
# MGYA00645559        Assembly    MGYS00006231  MGYA00645559  None
# MGYA00645571        Assembly    MGYS00006231  MGYA00645571  None
#
#                                                          sample  \
# MGYA00645526  {'accession': 'SAMN24114695', 'ena_accessions'...
# MGYA00645548  {'accession': 'SAMN24114734', 'ena_accessions'...
# MGYA00645551  {'accession': 'SAMN24114802', 'ena_accessions'...
# MGYA00645559  {'accession': 'SAMN24114786', 'ena_accessions'...
# MGYA00645571  {'accession': 'SAMN24114738', 'ena_accessions'...
#
#                                                        assembly  \
# MGYA00645526  {'updated_at': '2026-04-30T22:25:40.680000+00:...
# MGYA00645548  {'updated_at': '2026-04-30T22:25:41.667000+00:...
# MGYA00645551  {'updated_at': '2026-04-30T22:25:42.609000+00:...
# MGYA00645559  {'updated_at': '2026-04-30T22:25:43.561000+00:...
# MGYA00645571  {'updated_at': '2026-04-30T22:25:44.649000+00:...
#
#              pipeline_version  \
# MGYA00645526               V5
# MGYA00645548               V5
# MGYA00645551               V5
# MGYA00645559               V5
# MGYA00645571               V5
#
#                                                        read_run  \
# MGYA00645526  [{'experiment_type': 'Metagenomic', 'instrumen...
# MGYA00645548  [{'experiment_type': 'Metagenomic', 'instrumen...
# MGYA00645551  [{'experiment_type': 'Metagenomic', 'instrumen...
# MGYA00645559  [{'experiment_type': 'Metagenomic', 'instrumen...
# MGYA00645571  [{'experiment_type': 'Metagenomic', 'instrumen...
#
#              quality_control_summary  \
# MGYA00645526                      {}
# MGYA00645548                      {}
# MGYA00645551                      {}
# MGYA00645559                      {}
# MGYA00645571                      {}
#
#                                                       downloads  \
# MGYA00645526  [{'file_type': 'fasta', 'download_type': 'Sequ...
# MGYA00645548  [{'file_type': 'fasta', 'download_type': 'Sequ...
# MGYA00645551  [{'file_type': 'fasta', 'download_type': 'Sequ...
# MGYA00645559  [{'file_type': 'fasta', 'download_type': 'Sequ...
# MGYA00645571  [{'file_type': 'fasta', 'download_type': 'Sequ...
#
#                                                     results_dir metadata
# MGYA00645526  https://ftp.ebi.ac.uk/pub/databases/metagenomi...       {}
# MGYA00645548  https://ftp.ebi.ac.uk/pub/databases/metagenomi...       {}
# MGYA00645551  https://ftp.ebi.ac.uk/pub/databases/metagenomi...       {}
# MGYA00645559  https://ftp.ebi.ac.uk/pub/databases/metagenomi...       {}
# MGYA00645571  https://ftp.ebi.ac.uk/pub/databases/metagenomi...       {}
